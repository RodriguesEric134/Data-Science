# %%
import pandas as pd

# %%
base = pd.read_csv('churn.csv', sep=';')
base
# Out:
#        X0   X1  X2         X3  X4  X4.1        X6  X7  X8  X9         X10  X11
# 0       1  619  RS   Feminino  42     2         0   1   1   1  10134888.0    1
# 1       2  608  SC   Feminino  41     1   8380786   1   0   1  11254258.0    0
# 2       3  502  RS   Feminino  42     8   1596608   3   1   0  11393157.0    1
# 3       4  699  RS   Feminino  39     1         0   2   0   0   9382663.0    0
# 4       5  850  SC   Feminino  43     2  12551082   1   1   1    790841.0    0
# ..    ...  ...  ..        ...  ..   ...       ...  ..  ..  ..         ...  ...
# 994   996  838  SC  Masculino  43     9  12310588   2   1   0  14576583.0    0
# 995   997  610  SC  Masculino  29     9         0   3   0   1   8391224.0    0
# 996   998  811  SC  Masculino  44     3         0   2   0   1   7843973.0    0
# 997   999  587  SC  Masculino  62     7  12128627   1   0   1    677692.0    0
# 998  1000  811  PR   Feminino  28     4  16773882   2   1   1    990342.0    0
#
# [999 rows x 12 columns]

# %%
base[base["X3"] == "Feminino"]
# Out:
#        X0   X1  X2        X3  X4  X4.1        X6  X7  X8  X9         X10  X11
# 0       1  619  RS  Feminino  42     2         0   1   1   1  10134888.0    1
# 1       2  608  SC  Feminino  41     1   8380786   1   0   1  11254258.0    0
# 2       3  502  RS  Feminino  42     8   1596608   3   1   0  11393157.0    1
# 3       4  699  RS  Feminino  39     1         0   2   0   0   9382663.0    0
# 4       5  850  SC  Feminino  43     2  12551082   1   1   1    790841.0    0
# ..    ...  ...  ..       ...  ..   ...       ...  ..  ..  ..         ...  ...
# 989   991  722  RS  Feminino  49     3  16819766   1   1   0  14076557.0    1
# 991   993  615  RS  Feminino  35     2   9744002   2   1   1   1398161.0    0
# 992   994  752  PR  Feminino  42     3   6504608   2   0   1  14013928.0    0
# 993   995  661  SC  Feminino  28     7   9535749   1   0   0  10229715.0    0
# 998  1000  811  PR  Feminino  28     4  16773882   2   1   1    990342.0    0
#
# [461 rows x 12 columns]

# %%
base["X4"].min()
# Out:
# -20

# %%
base["X4"].max()
# Out:
# 140

# %%
base_genero = base[(base["X2"] == "PR")  & (base["X3"] == "Feminino")]
base_genero
# Out:
#        X0   X1  X2        X3  X4  X4.1        X6  X7  X8  X9           X10  \
# 7       8  376  PR  Feminino  29     4  11504674   4   1   0  1.193469e+10
# 45     46  776  PR  Feminino  32     4  10942113   2   1   1  1.265175e+07
# 46     47  829  PR  Feminino  27     9  11204567   1   1   1  1.197082e+07
# 47     48  637  PR  Feminino  39     9   1378438   1   1   1  1.176228e+06
# 49     50  776  PR  Feminino  37     2  10376922   2   1   0  1.940991e+07
# ..    ...  ...  ..       ...  ..   ...       ...  ..  ..  ..           ...
# 964   966  683  PR  Feminino  43     4  11588804   1   1   1  1.173492e+07
# 981   983  749  PR  Feminino  44     0   7149779   2   0   0  1.510838e+06
# 983   985  614  PR  Feminino  35     6  12810028   1   0   0           NaN
# 992   994  752  PR  Feminino  42     3   6504608   2   0   1  1.401393e+07
# 998  1000  811  PR  Feminino  28     4  16773882   2   1   1  9.903420e+05
#
#      X11
# 7      1
# 45     0
# 46     1
# 47     1
# 49     0
# ...
